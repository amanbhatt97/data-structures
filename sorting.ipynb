# %% [markdown]
# ## **Sorting**

# %% [markdown]
# **Algorithm Visualization**: https://www.hackerearth.com/practice/algorithms/sorting/selection-sort/visualize/

# %% [markdown]
# ### **Check for sorted array**

# %%
#------ check if array is sorted or not -----#
def is_sorted(arr):

    # initialize that array is already sorted
    sorted = True

    # loop over each element of array
    for i in range(len(arr) - 1):

        if arr[i] > arr[i + 1]:

            sorted = False

    return sorted

# %%
arr = [5, 5, 6, 56]
is_sorted(arr)
# Out:
# True

# %% [markdown]
# ### **Monkey Sort**

# %%
# import random module
import random

# create a list
L = [1, 2, 3, 4]

# shuffle the list
random.shuffle(L)

# %%
L
# Out:
# [1, 4, 3, 2]

# %%
#----- monkey sort -----#
def monkey_sort(arr):

    # loop till array is sorted
    while not is_sorted(arr):

        # shuffle the list
        random.shuffle(arr)

        # print the list after every loop
        print(arr)

    print('\nSorted array: ',arr)

# %%
monkey_sort([2,7,8,2,1,45,24,46])
# Out:
# [7, 24, 2, 46, 2, 45, 1, 8]
# [7, 2, 1, 2, 45, 8, 46, 24]
# [2, 1, 24, 7, 8, 46, 2, 45]
# [24, 8, 2, 1, 2, 45, 7, 46]
# [2, 2, 45, 1, 7, 46, 8, 24]
# [24, 7, 2, 2, 1, 46, 8, 45]
# [1, 2, 46, 2, 24, 7, 45, 8]
# [46, 24, 8, 2, 45, 7, 1, 2]
# [8, 2, 46, 45, 2, 7, 24, 1]
# [1, 24, 2, 2, 7, 8, 45, 46]
# [8, 1, 24, 2, 7, 2, 46, 45]
# [1, 8, 2, 46, 2, 24, 7, 45]
# [1, 45, 7, 2, 8, 46, 2, 24]
# [8, 46, 7, 24, 2, 2, 45, 1]
# [1, 7, 46, 2, 2, 45, 8, 24]
# [2, 7, 45, 46, 8, 1, 2, 24]
# [7, 2, 46, 45, 24, 1, 2, 8]
# [2, 24, 46, 2, 8, 45, 1, 7]
# [8, 45, 2, 24, 46, 7, 1, 2]
# [8, 24, 2, 1, 7, 46, 45, 2]
# [7, 45, 24, 8, 46, 1, 2, 2]
# [45, 7, 46, 24, 2, 8, 1, 2]
# [7, 2, 1, 2, 24, 8, 46, 45]
# [45, 2, 7, 1, 46, 2, 8, 24]
# [24, 1, 45, 7, 2, 46, 8, 2]
# [2, 45, 2, 24, 7, 46, 8, 1]
# [45, 1, 46, 2, 7, 24, 2, 8]
# [46, 8, 45, 7, 2, 1, 24, 2]
# [8, 2, 46, 24, 7, 45, 1, 2]
# [24, 45, 2, 7, 2, 8, 46, 1]
# [46, 45, 1, 24, 2, 8, 7, 2]
# [46, 24, 45, 1, 2, 7, 8, 2]
# [2, 46, 24, 7, 45, 8, 1, 2]
# ...

# %% [markdown]
# ### **Bubble Sort**

# %%
#----- bubble sort -----#
def bubble_sort(arr):

    # loop for passes
    for passes in range(len(arr) - 1):

        # loop for number of comparisions
        for comparisons in range(len(arr) - 1 - passes):

            # comparison
            if arr[comparisons] > arr[comparisons + 1]:

                # swapping
                arr[comparisons], arr[comparisons + 1] = arr[comparisons + 1], arr[comparisons] 

    # return sorted array
    return arr

# %%
bubble_sort([2,7,8,2,1,45,24,46])
# Out:
# [1, 2, 2, 7, 8, 24, 45, 46]
